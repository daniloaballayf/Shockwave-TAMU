# %% [markdown]
# # Continuity Equation

# %% [markdown]
# We look to solve the continuity equation for a given flow for a one dimensional flow.
#
# $$ \frac{\partial \rho}{\partial t} + \frac{\partial}{\partial x}\left(\rho u\right) = 0$$

# %%
import os
import sys

sys.path.append(os.path.join(os.path.abspath(''), '../'))

import numpy as np
from solver.continuity import FCT, laxwendroff
import matplotlib
import matplotlib.pyplot as plt

# %%
# Parameters
L = 1.0           # Length of the domain
T = 1.0           # Total simulation time
Nx = 5000         # Number of spatial points
Nt = 10000        # Number of time steps
dx = L / (Nx - 1)
dt = T / Nt

# %%
# Initial conditions
x = np.linspace(0, L, Nx)
v = 0.8 # We are considering a constant velocity problem.
u = v * np.ones(Nx) 
comp_t = 0.5
rho = np.exp(-(x-0.1*L)**2 /0.001)
sol_ext = np.exp(-((x - v*comp_t)-0.1*L)**2 /0.001)

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8))
axs[0].plot(x, rho, label='Initial Density', color='blue')
axs[0].set_title('Initial Density')
axs[0].set_xlabel('x')
axs[0].set_ylabel('Density')
axs[0].legend()

axs[1].plot(x, u, label='Initial Velocity', color='orange')
axs[1].set_title('Initial Velocity')
axs[1].set_xlabel('x')
axs[1].set_ylabel('Velocity')
axs[1].legend()

# %% [markdown]
# ### FCT Algorithm

# %%
solution = FCT(x, u, rho, dt, Nt)

# %%
idx = int(comp_t/dt)
plt.plot(x, sol_ext, label='Exact Solution', color='black', linestyle='dashed')
plt.plot(x, solution[:,idx], label=f'Density at {T * idx/Nt}')
plt.title('Numerical Solution of Continuity Equation')
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
err = np.linalg.norm(np.abs(sol_ext - solution[:,idx]))/np.linalg.norm(sol_ext)

print(f'Relative error: {err}')
# Out:
# Relative error: 0.03924601357384403

# %% [markdown]
# ### Lax-Wendroff

# %%
rho_sol = laxwendroff(x, u, rho, dt, Nt)

# %%
idx = int(comp_t/dt)
plt.plot(x, sol_ext, label='Exact Solution', color='black', linestyle='dashed')
plt.plot(x, rho_sol[:,idx], label=f'Density at {T * idx/Nt}')
plt.title('Numerical Solution of Continuity Equation')
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
err = np.linalg.norm(np.abs(sol_ext - rho_sol[:,idx]))/np.linalg.norm(sol_ext)

print(f'Relative error: {err}')
# Out:
# Relative error: 0.00030945929623225514

# %% [markdown]
# ## Periodic boundary conditions

# %%
# Parameters
L = 1.0           # Length of the domain
T = 1.0           # Total simulation time
Nx = 5000         # Number of spatial points
Nt = 20000        # Number of time steps
dx = L / (Nx - 1)
dt = T / Nt

# %%
# Initial conditions
x = np.linspace(0, L, Nx)
u = 2*np.ones(Nx)        # Velocity
rho = np.zeros(Nx)       # Example initial density profile
rho[:Nx//2] = 0
rho[Nx//2:] = 1

# %%
fig, axs = plt.subplots(2, 1, figsize=(8, 8))
axs[0].plot(x, rho, label='Initial Density', color='blue')
axs[0].set_title('Initial Density')
axs[0].set_xlabel('x')
axs[0].set_ylabel('Density')
axs[0].legend()

axs[1].plot(x, u, label='Initial Velocity', color='orange')
axs[1].set_title('Initial Velocity')
axs[1].set_xlabel('x')
axs[1].set_ylabel('Velocity')
axs[1].legend()

# %%
solution_per = FCT(x, u, rho, dt, Nt, BC='periodic')

# %%
idx = 10000
plt.plot(x, solution_per[:,idx], label=f'Density at {T * idx/Nt}')
plt.title('Numerical Solution of Continuity Equation')
plt.xlabel('x')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ### Animation

# %%
import matplotlib.animation as animation
# Initialize plot
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2, color='blue', label='Density')
ax.legend()
ax.set_xlim(0, 1)
ax.set_ylim(-0.2, 1.2)
ax.set_xlabel('x')
ax.set_ylabel('Density')

# Function to initialize plot
def init():
    line.set_data([], [])
    return line,

# Function to animate plot
def animate(i):
    y = solution_per[:,i]   # Change to solution to animate
    line.set_data(x, y)
    ax.set_title(f"Solution - {i*dt}") # Update title with file name
    return line,

# Create animation
ani = animation.FuncAnimation(fig, animate, init_func=init, frames=Nt+1, interval=200, blit=True)

# Save animation as a gif (optional)
ani.save('animations/C/density_periodic.gif', writer='pillow', fps=24)

# Show plot
plt.show()
